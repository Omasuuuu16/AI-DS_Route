# %% [markdown]
# hello

# %%
print("welcome")
# Out:
# welcome

# %%
x=5
x=6
print(x)
# Out:
# 6

# %%
var=2
_var=3
var_2=4


x=8 #int
y=8.5 #float
a=True #boolean
x=5
print(x,y)
# Out:
# 5 8.5

# %%
x
# Out:
# 5

# %%
#none type
t=None
u=None
a=0
print(type(t))
print(type(u))
# Out:
# <class 'NoneType'>
# <class 'NoneType'>

# %%
id(t)
# Out:
# 140703497060048

# %%
id(u)
# Out:
# 140703497060048

# %%
print(t)
print(y)
# Out:
# None
# 8.5

# %%
t
y
# Out:
# 8.5

# %%
print("x= ",x)
print(f"x=  {x}")
# Out:
# x=  5
# x=  5

# %%
x=4
y=2
print("sum = " , x+y)
print("sub =",x-y)
print("mult = ",x*y)
print("divide = ", x/y)
print("modulus = ",x%y)
print("power = ",x**y)
# Out:
# sum =  6
# sub = 2
# mult =  8
# divide =  2.0
# modulus =  0
# power =  16

# %%
15 // 3 #5
#5*3=15

15%2 #1
# Out:
# 1

# %%
num1=10
num2=0
print("sum = " , num1+num2)
print("sub =",num1-num2)
print("mult = ",num1*num2)
print("divide = ", num1/num2)
# Out:
# sum =  10
# sub = 10
# mult =  0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[29], line 6
#       4 print("sub =",num1-num2)
#       5 print("mult = ",num1*num2)
# ----> 6 print("divide = ", num1/num2)
#
# ZeroDivisionError: division by zero

# %%
a=150
b=22
ms =a*b
print(ms)
# Out:
# 3300

# %%
#string
st="hello"
s='hi'
st[0]#h
len(st)#5
# start from zero (first element) end len()-1 (last element)
st[-1] #o
st[-2] #l
st[-len(st)]#h
st[len(st)]#error كانى بقةبه عاوز رقم 5
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 10
#       8 st[-2] #l
#       9 st[-len(st)]#h
# ---> 10 st[len(st)]
#
# IndexError: string index out of range

# %%
st="hello"

# %%
#slicing
st[0 : 1]
# Out:
# 'h'

# %%
st[0 : 2]
# Out:
# 'he'

# %%
st[3:5]
# Out:
# 'lo'

# %%
st="hello"
st[-3:-1]
# Out:
# 'll'

# %%
st[0:4:2]
# Out:
# 'hl'

# %%
st[:4:2]# هو فاهم من اول 0
# Out:
# 'hl'

# %%
st[ ::2]
# Out:
# 'hlo'

# %%
st[::]
# Out:
# 'hello'

# %%
st[::-1]
# Out:
# 'olleh'

# %%
"hi " + "ali"
# Out:
# 'hi ali'

# %%
"hi "*3
# Out:
# 'hi hi hi '

# %%
x=8
print("hi" , x)
print("hi"+x)
# Out:
# hi 8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 3
#       1 x=8
#       2 print("hi" , x)
# ----> 3 print("hi"+x)
#
# TypeError: can only concatenate str (not "int") to str

# %%
st="ali"
print("hi",st)
print("hi" + st)
# Out:
# hi ali
# hiali

# %%
st="ali"
"A" + st[1:]
# Out:
# 'Ali'

# %%
#split
st = "hello world name age"
st.split(" ")
# Out:
# ['hello', 'world', 'name', 'age']

# %%
st = "hello,world,name,age"
st.split(",")
# Out:
# ['hello', 'world', 'name', 'age']

# %%
st = "hello world oh"
st.split("o",2)
# Out:
# ['hell', ' w', 'rld oh']

# %%
st.find("o") #sub string
#بيجيب اول مره بس
# Out:
# 4

# %%
st.find("ll",6,10)
# Out:
# -1

# %%
st.replace("o", "O")
# Out:
# 'hellO wOrld Oh'

# %%
st = "hello world"

# %%
st.upper()
# Out:
# 'HELLO WORLD'

# %%
st.capitalize()
# Out:
# 'Hello world'

# %%
S = """Python is a high-level, general-purpose and very popular programming
language. The Python programming language is being used in Web Development,
Machine Learning applications, Computer Vision, along with all the cutting-edge
technology in the software industry"""
print(len(S))
print(S.count("Python"))
print(S.find("Machine Learning"))
print(S.replace("Python","C++"))
N=""""C++ is a high-level, general-purpose and very popular programming
language. The C++ programming language is being used in Web Development,
Machine Learning applications, Computer Vision, along with all the cutting-edge
technology in the software industry"""
print(N.find("Machine Learning"))
print(N.upper())
# Out:
# 260
# 2
# 145
# C++ is a high-level, general-purpose and very popular programming
# language. The C++ programming language is being used in Web Development,
# Machine Learning applications, Computer Vision, along with all the cutting-edge
# technology in the software industry
# 140
# "C++ IS A HIGH-LEVEL, GENERAL-PURPOSE AND VERY POPULAR PROGRAMMING
# LANGUAGE. THE C++ PROGRAMMING LANGUAGE IS BEING USED IN WEB DEVELOPMENT,
# MACHINE LEARNING APPLICATIONS, COMPUTER VISION, ALONG WITH ALL THE CUTTING-EDGE
# TECHNOLOGY IN THE SOFTWARE INDUSTRY

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 len(S )
#
# NameError: name 'S' is not defined
